# %%
REST_URL = "http://0.0.0.0:8545"

# %%
from web3 import Web3
from web3.middleware import geth_poa_middleware

# %%
w3 = Web3(Web3.HTTPProvider(REST_URL))

w3.isConnected()
# Out:
# True

# %%
w3.middleware_onion.inject(geth_poa_middleware, layer=0)

# %%
trans = w3.eth.get_transaction('0x0e3d45ec3e1d145842ce5bc56ad168e4a98508e0429da96c1ff89f11076da36d')
trans
# Out:
# ---------------------------------------------------------------------------
# TransactionNotFound                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 trans = w3.eth.get_transaction('0x0e3d45ec3e1d145842ce5bc56ad168e4a98508e0429da96c1ff89f11076da36d')
#       2 trans
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/eth.py:737, in Eth.get_transaction(self, transaction_hash)
#     736 def get_transaction(self, transaction_hash: _Hash32) -> TxData:
# --> 737     return self._get_transaction(transaction_hash)
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/module.py:57, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#      55     return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56 result_formatters, error_formatters, null_result_formatters = response_formatters
# ---> 57 result = w3.manager.request_blocking(method_str,
#      58                                      params,
#      59                                      error_formatters,
#      60                                      null_result_formatters)
#      61 return apply_result_formatters(result_formatters, result)
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/manager.py:198, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     194 """
#     195 Make a synchronous request using the provider
#     196 """
#     197 response = self._make_request(method, params)
# --> 198 return self.formatted_response(response,
#     199                                params,
#     200                                error_formatters,
#     201                                null_result_formatters)
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/manager.py:177, in RequestManager.formatted_response(response, params, error_formatters, null_result_formatters)
#     172 # NULL_RESPONSES includes None, so return False here as the default
#     173 # so we don't apply the null_result_formatters if there is no 'result' key
#     174 elif response.get('result', False) in NULL_RESPONSES:
#     175     # null_result_formatters raise either a BlockNotFound
#     176     # or a TransactionNotFound error, depending on the method called
# --> 177     apply_null_result_formatters(null_result_formatters, response, params)
#     178     return response['result']
#     179 elif response.get('result') is not None:
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/manager.py:82, in apply_null_result_formatters(null_result_formatters, response, params)
#      76 def apply_null_result_formatters(
#      77     null_result_formatters: Callable[..., Any],
#      78     response: RPCResponse,
#      79     params: Optional[Any] = None,
#      80 ) -> RPCResponse:
#      81     if null_result_formatters:
# ---> 82         formatted_resp = pipe(params, null_result_formatters)
#      83         return formatted_resp
#      84     else:
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/cytoolz/functoolz.pyx:666, in cytoolz.functoolz.pipe()
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/cytoolz/functoolz.pyx:641, in cytoolz.functoolz.c_pipe()
#
# File ~/.cache/pypoetry/virtualenvs/onchain-oe0ZY51D-py3.10/lib/python3.10/site-packages/web3/_utils/method_formatters.py:656, in raise_transaction_not_found(params)
#     653 except IndexError:
#     654     message = "Unknown transaction hash"
# --> 656 raise TransactionNotFound(message)
#
# TransactionNotFound: Transaction with hash: '0x0e3d45ec3e1d145842ce5bc56ad168e4a98508e0429da96c1ff89f11076da36d' not found.
